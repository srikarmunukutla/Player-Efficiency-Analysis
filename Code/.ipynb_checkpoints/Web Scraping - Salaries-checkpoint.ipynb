# %%
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
url = "http://www.espn.com/nba/salaries/_/year/2019/seasontype/4"
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")

header = soup.find("tr", attrs={"class": "colhead"})
columns = [col.get_text() for col in header.find_all("td")]
columns = columns[1:]

df_salaries = pd.DataFrame(columns=columns)
df_salaries
# Out:
# Empty DataFrame
# Columns: [OWS, DWS, Win Shares, WS/48, OBPM, DBPM, BPM, VORP, Wins Above Replacement]
# Index: []

# %%
for a in range(1, 503, 40):
    
    if a == 1:
        url = "http://www.espn.com/nba/salaries/_/year/2019/seasontype/4"
        page = requests.get(url)
        soup = BeautifulSoup(page.text, "html.parser")
    else:
        url = "http://www.espn.com/nba/salaries/_/year/2019/page/{}/seasontype/4".format(int(a/40)+1)
        page = requests.get(url)
        soup = BeautifulSoup(page.text, "html.parser")

    players = soup.find_all("tr", attrs = {"class":re.compile("row")})
    for player in players:
        stats = []
        i = 0
        for data in player.find_all("td"):
            string = data.get_text()
            if i == 1:
                name = string.split(",")[0]
                stats.append(name)
            elif i == 2:
                team = string
                stats.append(team)
            elif i == 3:
                space = ""
                salary = int(space.join(string[1:].split(",")))
                stats.append(salary)
            i += 1

        temp_df = pd.DataFrame(stats).transpose()
        temp_df.columns = columns

        df_salaries = pd.concat([df_salaries, temp_df], ignore_index=True)

df_salaries
# Out:
#                         NAME                    TEAM    SALARY
# 0              Stephen Curry   Golden State Warriors  37457154
# 1                 Chris Paul         Houston Rockets  35654150
# 2               LeBron James      Los Angeles Lakers  35654150
# 3          Russell Westbrook   Oklahoma City Thunder  35654150
# 4              Blake Griffin         Detroit Pistons  32088932
# 5             Gordon Hayward          Boston Celtics  31214295
# 6                 Kyle Lowry         Toronto Raptors  31200000
# 7                Paul George   Oklahoma City Thunder  30560700
# 8                Mike Conley       Memphis Grizzlies  30521115
# 9               James Harden         Houston Rockets  30421854
# 10              Kevin Durant   Golden State Warriors  30000000
# 11              Paul Millsap          Denver Nuggets  29230769
# 12                Al Horford          Boston Celtics  28928709
# 13            Damian Lillard  Portland Trail Blazers  27977689
# ...

# %%
df_salaries.to_csv(r"/Users/Srikar/Desktop/Sports/Data/salaries18-19.csv", index=False, sep=',', encoding='utf-8')

# %%
df_salaries = pd.read_csv("/Users/Srikar/Desktop/Sports/Data/salaries18-19.csv")
final_df = pd.read_csv("/Users/Srikar/Desktop/Sports/Data/stats18-19.csv")

# %%
final_df.insert(final_df.shape[1]-1, "SALARY", int(0))
# number of columns is also len(final_df.columns)

# %%
for ind in range(final_df.shape[0]):
    for row in range(df_salaries.shape[0]):
        if final_df.loc[ind, "NAME"] == df_salaries.loc[row, "NAME"]:
            final_df.loc[ind, "TEAM"] = df_salaries.loc[row, "TEAM"]
            final_df.loc[ind, "SALARY"] = df_salaries.loc[row, "SALARY"]
            break
final_df.head()
# Out:
#                     NAME                   TEAM POS  GP   MIN   PTS   FGM  \
# 0           James Harden        Houston Rockets  PG  78  36.8  36.1  10.8
# 1            Paul George  Oklahoma City Thunder  SF  77  36.9  28.0   9.2
# 2  Giannis Antetokounmpo        Milwaukee Bucks  PF  72  32.8  27.7  10.0
# 3            Joel Embiid     Philadelphia 76ers   C  64  33.7  27.5   9.1
# 4          Stephen Curry  Golden State Warriors  PG  69  33.8  27.3   9.2
#
#     FGA   FG%  3PM  ...   FT%   REB  AST  STL  BLK   TO  DD2  TD3    SALARY  \
# 0  24.5  44.2  4.8  ...  87.9   6.6  7.5  2.0  0.7  5.0   34    7  30421854
# 1  21.0  43.8  3.8  ...  83.9   8.2  4.1  2.2  0.4  2.7   24    1  30560700
# 2  17.3  57.8  0.7  ...  72.9  12.5  5.9  1.3  1.5  3.7   54    5  24157303
# 3  18.7  48.4  1.2  ...  80.4  13.6  3.7  0.7  1.9  3.5   58    2  25467250
# 4  19.4  47.2  5.1  ...  91.6   5.3  5.2  1.3  0.4  2.8    3    0  37457154
#
#      PER
# 0  30.62
# 1  23.32
# 2  30.95
# 3  26.21
# 4  24.45
# ...

# %%
final_df.to_csv(r"/Users/Srikar/Desktop/Sports/Data/alldata18-19.csv", index=False, sep=',', encoding='utf-8')
